# %% [markdown]
# # Comparing the overlap between inferred tags with a supervised tagger

# %%
import spacy
import codecs

import numpy as np 

from tokenizations import get_alignments
from transformers import BertTokenizer
from tqdm import tqdm
from collections import Counter

# %%
def read_data(data_path='../../data/news/'):
    """Read 20news data, train only"""
    # use the cased data for NER, otherwise spacy does not work with uncased 
    with codecs.open(data_path + '20news.txt', encoding='utf-8') as fd:
        data = fd.readlines()
    train_idx = np.load(data_path + 'train_idx.npy')
    train_data = [data[i][: -1] for i in train_idx]
    return train_data

# %%
train_data = read_data()

# %%
pos_dict = {}
ent_dict = {}
token_bert2spacy = {}

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
nlp = spacy.load("en_core_web_sm", disable='parser')

# %%
for s in tqdm(train_data[:1000]):
    doc = nlp(s)

    spacy_tokenized = []
    for token in doc:
        if(token.pos_ not in pos_dict):
            pos_dict[token.pos_] = [token.text]
        else:
            pos_dict[token.pos_].append(token.text)
            spacy_tokenized.append(token.text)

    for ent in doc.ents:
        if(ent.label_ not in ent_dict): ent_dict[ent.label_] = [ent.text]
        else: ent_dict[ent.label_].append(ent.text)

    bert_tokenized = tokenizer.tokenize(s)

    bert2spacy, spacy2bert = get_alignments(bert_tokenized, spacy_tokenized)
    for w, w_ in enumerate(bert2spacy):
        w = bert_tokenized[w]
        if(w not in token_bert2spacy):
            token_bert2spacy[w] = []
        for wi in w_:
            token_bert2spacy[w].append(spacy_tokenized[wi])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:07<00:00, 131.22it/s]

# %%
bert_tokenized
# Out:
# ['(', 'hard', 'to', 'believe', ',', 'isn', "'", 't', 'it', '?', ')']

# %%
spacy_tokenized
# Out:
# ['(', 'hard', 'to', 'believe', ',', 'is', "n't", 'it', '?', ')']

# %%
bert2spacy
# Out:
# [[0], [1], [2], [3], [4], [5, 6], [6], [6], [7], [8], [9]]

# %%
for p in pos_dict:
    pos_dict[p] = Counter(pos_dict[p])
    
for e in ent_dict:
    ent_dict[e] = Counter(ent_dict[e])
    
for w in token_bert2spacy:
    token_bert2spacy[w] = Counter(token_bert2spacy[w])

# %%
pos_dict
# Out:
# {'DET': Counter({'a': 262,
#           'the': 658,
#           'an': 43,
#           'some': 22,
#           'no': 40,
#           'this': 50,
#           'those': 5,
#           'each': 1,
#           'these': 12,
#           'either': 1,
#           'that': 10,
#           'every': 6,
#           'any': 17,
#           'another': 5,
#           'all': 15,
#           'whose': 3,
#           'f': 1,
#           'which': 4,
#           'both': 2,
#           'half': 1,
#           'twice': 1,
#           'whatever': 1,
#           'quite': 1,
#           'what': 2,
#           'b': 1}),
#  'NUM': Counter({'hundred': 1,
#           '80': 2,
#           '90': 2,
#           '100': 3,
#           '200': 1,
#           '1000': 1,
#           'one': 35,
#           '2': 22,
#           'two': 10,
#           '300': 2,
#           '250': 1,
#           '7': 12,
#           '1919': 1,
#           '3': 9,
#           '4': 6,
#           '5': 12,
#           '1940': 1,
#           '1': 14,
#           '000': 2,
#           '10': 6,
#           '20': 8,
#           '13': 2,
#           '17': 4,
#           '8': 10,
#           '00': 5,
#           '24': 4,
#           '1200': 1,
#           '2400': 1,
#           '4800': 1,
#           '9600': 1,
#           '40': 3,
#           '33': 3,
#           '1239': 2,
#           '1268': 1,
#           '6': 9,
#           '38': 1,
#           '16': 6,
#           "an'x": 1,
#           '73': 1,
#           'five': 2,
#           '403': 1,
#           '679': 1,
#           '1100': 1,
#           '800': 2,
#           '21': 3,
#           'three': 2,
#           '48': 2,
#           '12': 3,
#           '138': 1,
#           '9': 3,
#           '26': 1,
#           'four': 1,
#           '323': 1,
#           '25': 2,
#           '1149': 1,
#           '1182': 1,
#           '76': 4,
#           '77': 1,
#           '776': 1,
#           '2333': 1,
#           '408': 1,
#           '996': 1,
#           '1010': 1,
#           '617': 1,
#           '271': 1,
#           '2714': 1,
#           '207': 1,
#           '573534': 1,
#           'zero': 1,
#           '14': 4,
#           '1993': 3,
#           '1pq2ofinne2': 1,
#           '201': 1,
#           '93': 2,
#           'seven': 1,
#           '50': 4,
#           'c610': 1,
#           '650': 1,
#           '72': 2,
#           '32': 2,
#           '1915': 1,
#           '91': 2,
#           '43': 2,
#           '30': 5,
#           '256k': 3,
#           '27': 3,
#           '1190': 1,
#           '22': 4,
#           '0': 6,
#           '49': 1,
#           '52': 1,
#           '80386': 1,
#           '45': 3,
#           '1948': 2,
#           '1949': 1,
#           '.': 2,
#           '1978': 1,
#           'thirty': 2,
#           '1850': 1,
#           'u2': 1,
#           '15': 1,
#           '29': 1,
#           '1141': 1,
#           '580': 2,
#           '1957': 1,
#           '1145': 1,
#           '1131': 1,
#           '106': 1,
#           '96': 1,
#           '550': 1,
#           'million': 5,
#           '1976': 1,
#           '150': 2,
#           '07': 1,
#           '37': 1,
#           '94318': 1,
#           '646': 1,
#           '7508': 1,
#           '30332': 1,
#           '36': 1,
#           '1qsk9d': 1,
#           '1986': 2,
#           '3129': 1,
#           '1005': 1,
#           '1057': 1,
#           '156': 1,
#           '152': 1,
#           '1174': 1,
#           '1147': 1,
#           '79': 2,
#           '262': 1,
#           '103': 1,
#           '111': 1,
#           '35': 1,
#           '98': 2,
#           '882': 1,
#           '84761': 1,
#           '5269': 1,
#           '5445': 1,
#           '510': 1,
#           '521': 1,
#           '3147': 1,
#           'n105': 1,
#           '2005': 1,
#           '1024': 1,
#           '02': 1,
#           '386': 1,
#           '64': 2,
#           '3074': 1,
#           '199': 1,
#           '28': 1,
#           '68030': 1,
#           '+': 1,
#           '94': 1,
#           'eight': 1,
#           '655321': 1,
#           "'": 2,
#           '68': 1,
#           '327': 1,
#           '1168x832': 1,
#           '5513': 1,
#           '53150': 1}),
#  'NOUN': Counter({'cars': 2,
#           'vomiting': 1,
#           'topic': 3,
#           'electricity': 2,
#           'space': 2,
#           'earth': 5,
#           'orbit': 1,
#           'vehicle': 1,
#           'prosecution': 1,
#           'drivers': 4,
#           'influence': 2,
#           'variety': 1,
#           'drugs': 1,
#           'controllers': 2,
#           'awd': 1,
#           'line': 10,
#           'model': 3,
#           'chain': 1,
#           'wheel': 2,
#           'km': 1,
#           'skin': 3,
#           'egg': 1,
#           'face': 1,
#           'disease': 1,
#           'disorders': 1,
#           'universe': 1,
#           'wings': 1,
#           'teh': 1,
#           'joints': 1,
#           'cents': 2,
#           'distribution': 7,
#           'disks': 4,
#           'disk': 7,
#           'stocks': 1,
#           'members': 3,
#           'course': 5,
#           'politics': 1,
#           'time': 19,
#           'people': 20,
#           'heresy': 1,
#           'language': 3,
#           'author': 1,
#           'xv': 1,
#           'monitor': 4,
#           'extension': 3,
#           'cable': 4,
#           'chance': 3,
#           'smythe': 1,
#           'division': 3,
#           'finals': 1,
#           'one': 12,
#           'year': 12,
#           'penguins': 3,
#           'scoring': 1,
#           'threats': 1,
#           'judgment': 2,
#           'making': 1,
#           'example': 4,
#           'animals': 3,
#           'food': 1,
#           'inning': 1,
#           'bases': 1,
#           'outs': 2,
#           'hitter': 3,
#           'power': 7,
#           'pinch': 2,
#           'runner': 1,
#           'electronics': 1,
#           'industry': 1,
#           'labor': 1,
#           'pools': 1,
#           'beeps': 1,
#           'cassette': 1,
#           'tape': 1,
#           'thousands': 1,
#           'world': 14,
#           'standards': 1,
#           'fighters': 1,
#           'kery': 1,
#           'project': 1,
#           'bus': 5,
#           'card': 3,
#           'bitblaster': 1,
#           'micron': 1,
#           'cards': 1,
#           'questions': 7,
#           'com': 12,
#           'enemies': 1,
#           'organization': 10,
#           'lines': 14,
#           'hanuman': 1,
#           'lance': 1,
#           'today': 3,
#           'soul': 1,
#           'prism': 1,
#           'oguocha': 1,
#           'question': 7,
#           'genocide': 1,
#           'wife': 2,
#           'messengers': 1,
#           'heads': 2,
#           'country': 3,
#           'mark': 2,
#           'material': 2,
#           'spacelink': 1,
#           'missions': 1,
#           'absolutes': 1,
#           'opinions': 3,
#           'suggestions': 3,
#           'sun6850': 1,
#           'nrl': 1,
#           'subject': 36,
#           'article': 8,
#           'bottom': 1,
#           'screen': 2,
#           'bar': 1,
#           'black': 2,
#           'minutes': 3,
#           'extract': 1,
#           'himmler': 1,
#           'address': 1,
#           'party': 1,
#           'comrades': 1,
#           'trials': 1,
#           'criminals': 1,
#           'vol': 1,
#           'freebie': 1,
#           'favorite': 1,
#           'data': 7,
#           'research': 2,
#           'systems': 1,
#           'opinion': 7,
#           'fact': 9,
#           'person': 6,
#           'stoves': 1,
#           'metro': 1,
#           'areas': 2,
#           'religion': 2,
#           'cult': 1,
#           'test': 3,
#           '%': 4,
#           'crimes': 2,
#           'homicides': 1,
#           'ownership': 2,
#           'firearms': 2,
#           'lives': 1,
#           'ergs': 1,
#           '=': 1,
#           'tons': 1,
#           'tnt': 1,
#           'equivalent': 1,
#           'energy': 1,
#           'bomb': 2,
#           'drive': 5,
#           'standing': 2,
#           'package': 3,
#           'simtel20': 1,
#           'mirror': 1,
#           'sites': 1,
#           'testing': 1,
#           'ground': 2,
#           'tsiel': 1,
#           'adl': 3,
#           'relationship': 1,
#           'counterterrorism': 1,
#           'office': 1,
#           'reports': 3,
#           'ties': 1,
#           'terrorists': 1,
#           'cause': 1,
#           'laws': 3,
#           'rules': 3,
#           'future': 1,
#           "to'safeguards": 1,
#           'risk': 1,
#           'hepatitis': 1,
#           'atheists': 1,
#           'category': 1,
#           'programs': 5,
#           'broadcast': 1,
#           'use': 5,
#           'image': 5,
#           'quality': 1,
#           'encryption': 4,
#           'safety': 1,
#           'ski': 1,
#           'masks': 1,
#           'description': 1,
#           'chip': 3,
#           'operation': 2,
#           'management': 1,
#           'aspects': 1,
#           'code': 4,
#           'domain': 2,
#           'rsa': 1,
#           'routines': 2,
#           'library': 3,
#           'rsaref': 1,
#           'ripem': 1,
#           'math': 3,
#           'chalmers': 1,
#           'apple': 3,
#           'structure': 2,
#           'regions': 1,
#           'court': 3,
#           'mb': 2,
#           'ram': 1,
#           'dna': 1,
#           'urge': 1,
#           'easter': 1,
#           'cover': 3,
#           'mechanics': 1,
#           'answers': 2,
#           'bbs': 1,
#           'hours': 2,
#           'day': 3,
#           'bps': 1,
#           'bits': 4,
#           'stop': 2,
#           'bit': 13,
#           'parity': 1,
#           'logic': 3,
#           'reason': 4,
#           'thinking': 1,
#           'value': 3,
#           'exposition': 1,
#           'individuals': 2,
#           'moment': 2,
#           'lyuda': 2,
#           'prophecy': 1,
#           'exhort': 1,
#           'overlap': 1,
#           'scripture': 1,
#           'connor': 1,
#           'member': 2,
#           'government': 4,
#           'body': 3,
#           'overreaction': 1,
#           'case': 11,
#           'reply': 3,
#           'aas7': 1,
#           'hands': 1,
#           'knife': 1,
#           'invitation': 1,
#           'litigant': 1,
#           'ace': 1,
#           'hole': 1,
#           'verdict': 3,
#           'sense': 3,
#           'existence': 3,
#           'replacement': 3,
#           'fan': 1,
#           'lot': 11,
#           'quieter': 1,
#           'air': 2,
#           'thanks': 15,
#           'advance': 1,
#           'waikato': 1,
#           'ac': 1,
#           'method': 3,
#           'contact': 2,
#           'massacre': 1,
#           'epidemic': 1,
#           'bashing': 1,
#           'assault': 1,
#           'essence': 2,
#           'energies': 1,
#           'creation': 1,
#           'asimov': 1,
#           'christianity': 1,
#           'deathbed': 1,
#           'bribe': 1,
#           'money': 3,
#           'catalogue': 1,
#           'law': 9,
#           'chiropractors': 1,
#           'hospitals': 2,
#           'va': 1,
#           'chiropractor': 1,
#           'indicator': 1,
#           'performance': 2,
#           'set': 1,
#           'circumstances': 1,
#           'scholars': 1,
#           'words': 5,
#           'portions': 2,
#           'problem': 10,
#           'display': 3,
#           'grey': 1,
#           'colour': 3,
#           'levels': 1,
#           'exchange': 1,
#           'link': 1,
#           'establishment': 1,
#           'comments': 3,
#           'proposal': 2,
#           'dissemination': 1,
#           'discussion': 2,
#           'enrichment': 1,
#           'curve': 1,
#           'ball': 1,
#           'mail': 9,
#           'vax': 2,
#           'problems': 6,
#           'times': 6,
#           'shock': 1,
#           'kit': 1,
#           'shocks': 1,
#           'hand': 3,
#           'throttle': 1,
#           'lock': 1,
#           'scaling': 1,
#           'wart': 1,
#           'tumors': 1,
#           'necks': 1,
#           'backs': 1,
#           'scenario': 1,
#           'respect': 1,
#           'place': 8,
#           'hell': 3,
#           'car': 3,
#           'passionate': 1,
#           'following': 3,
#           'insurance': 1,
#           'hospital': 3,
#           'differences': 1,
#           'rate': 2,
#           'paper': 1,
#           'propane': 1,
#           'tsto': 1,
#           'launch': 6,
#           'system': 21,
#           'aircraft': 1,
#           'efficiencies': 1,
#           'hydrogen': 1,
#           'fuel': 3,
#           'days': 2,
#           'king': 2,
#           'confidince': 1,
#           'enforcement': 1,
#           'server': 4,
#           'machine': 8,
#           'memory': 2,
#           'requests': 1,
#           'symbols': 1,
#           'p': 1,
#           'block': 3,
#           'plaintext': 1,
#           'input': 4,
#           'output': 3,
#           'decryption': 1,
#           'parting': 1,
#           'christian': 4,
#           'parents': 2,
#           'si': 1,
#           'supply': 3,
#           'simplicity': 1,
#           'virtue': 1,
#           'previewers': 1,
#           'xview': 1,
#           'sunview': 1,
#           'values': 4,
#           'plane': 2,
#           'clergy': 1,
#           'beliefs': 2,
#           'event': 4,
#           'experience': 3,
#           'framework': 2,
#           'works': 2,
#           'word': 2,
#           'liberties': 2,
#           'rights': 6,
#           'witt': 1,
#           'thought': 4,
#           'resource': 2,
#           'conduct': 1,
#           'life': 6,
#           '@.': 1,
#           'pitt': 1,
#           'prediction': 1,
#           'playoffs': 1,
#           'window': 4,
#           'infante': 1,
#           'disasters': 2,
#           'love': 1,
#           'canal': 1,
#           'beach': 1,
#           'tmi': 1,
#           'ubvmsd': 1,
#           'configuration': 1,
#           'pulse': 2,
#           'beam': 1,
#           'steering': 1,
#           'adobe': 3,
#           'type': 1,
#           'manager': 1,
#           'sync': 1,
#           'separator': 1,
#           'purshase': 1,
#           'company': 5,
#           'panasonic': 1,
#           'cartridges': 1,
#           'issues': 3,
#           'ventures': 1,
#           'venture': 2,
#           'corporation': 1,
#           'a.': 3,
#           'act': 1,
#           'breach': 1,
#           'violation': 1,
#           'nonfulfillment': 1,
#           'introduction': 1,
#           'group': 4,
#           'anonymity': 1,
#           'repercussions': 1,
#           'usenet': 3,
#           'conventions': 1,
#           'mechanisms': 1,
#           "alt'groups": 1,
#           'past': 1,
#           'panda': 1,
#           'client': 3,
#           'theories': 1,
#           'information': 9,
#           'profession': 1,
#           'orientalist': 1,
#           'iosef': 1,
#           'director': 1,
#           'hermitage': 1,
#           'museum': 1,
#           'sex': 4,
#           'd': 3,
#           'reform': 1,
#           'team': 6,
#           'success': 1,
#           'steps': 1,
#           'proof': 1,
#           'authority': 2,
#           'teachings': 2,
#           'needs': 1,
#           'businesses': 1,
#           'adversaries': 1,
#           'security': 1,
#           'services': 5,
#           'companies': 1,
#           'checking': 2,
#           'table': 2,
#           'net': 3,
#           'quebec': 3,
#           'showings': 1,
#           'mit': 2,
#           'frame': 6,
#           'buffer': 3,
#           'twisto': 1,
#           'laughter': 1,
#           'tao': 1,
#           'info': 5,
#           'request': 1,
#           'terms': 2,
#           'kirilian': 1,
#           'photography': 1,
#           'fields': 1,
#           'objects': 2,
#           'simple': 1,
#           'pictures': 3,
#           'aura': 1,
#           'crowd': 2,
#           'couple': 4,
#           'tickets': 1,
#           'attitude': 1,
#           'founder': 1,
#           'lotus': 1,
#           'software': 5,
#           'lyricist': 1,
#           'rock': 1,
#           'band': 1,
#           'prices': 1,
#           'tervio': 1,
#           'dispatch': 1,
#           '16th': 1,
#           'actions': 2,
#           'alt': 3,
#           'atheism': 2,
#           'hostility': 1,
#           'phone': 3,
#           'conversation': 2,
#           'administrations': 1,
#           'priority': 1,
#           'items': 1,
#           'work': 2,
#           'comp': 3,
#           'period': 2,
#           'college': 1,
#           'simms': 4,
#           'q': 1,
#           'revelations': 1,
#           'reference': 5,
#           'fire': 2,
#           'unbelievers': 1,
#           'term': 1,
#           'effects': 1,
#           'drug': 3,
#           'findings': 1,
#           'investigators': 1,
#           'implications': 2,
#           'health': 1,
#           'countries': 3,
#           'typing': 1,
#           'writing': 1,
#           'rsi': 1,
#           'arm': 2,
#           'mine': 2,
#           'bowman': 1,
#           'way': 9,
#           'ice': 1,
#           'thing': 8,
#           'blues': 1,
#           'pump': 1,
#           'minor': 1,
#           'innings': 1,
#           'color': 5,
#           'alpha': 1,
#           'channel': 1,
#           'auis': 1,
#           'demo': 1,
#           'sphere': 2,
#           'allies': 1,
#           'manufacturer': 1,
#           'user': 2,
#           'patch': 1,
#           'restriction': 1,
#           'copy': 5,
#           'astronomy': 1,
#           'physics': 1,
#           'palette': 1,
#           'number': 9,
#           'hardware': 6,
#           'cells': 1,
#           'descriptors': 1,
#           'science': 4,
#           'cie': 1,
#           'xyz': 1,
#           'chromaticity': 1,
#           'scale': 1,
#           'diagram': 1,
#           'resultant': 1,
#           'epidemics': 1,
#           'command': 3,
#           'militia': 1,
#           'commander': 1,
#           'ismail': 1,
#           'hakki': 1,
#           'note': 2,
#           'target': 2,
#           'win': 3,
#           'game': 5,
#           'definition': 2,
#           'file': 9,
#           'hockey': 1,
#           'draft': 1,
#           'standings': 1,
#           'week': 4,
#           'posn': 2,
#           'proj': 1,
#           'cash': 1,
#           'list': 6,
#           'bounces': 1,
#           'screwups': 1,
#           'woody': 1,
#           'formats': 1,
#           'pc': 1,
#           'evidence': 6,
#           'intro': 1,
#           'econ': 1,
#           'lecture': 1,
#           'costs': 3,
#           'opportunity': 2,
#           'source': 6,
#           'packages': 1,
#           'riles': 1,
#           'catcher': 2,
#           'aaa': 1,
#           'roster': 1,
#           'mother': 2,
#           'savior': 1,
#           'others': 5,
#           'son': 3,
#           'players': 2,
#           'rods': 1,
#           'springs': 2,
#           'byeeeee': 1,
#           'driver': 3,
#           'man': 7,
#           'chuck': 1,
#           'rogers': 1,
#           'car377': 1,
#           'torreys': 1,
#           'jury': 1,
#           'guarantee': 1,
#           'books': 2,
#           'impact': 2,
#           'violence': 1,
#           'jokes': 1,
#           'crohns': 1,
#           'appendix': 1,
#           'consultations': 1,
#           'industries': 1,
#           'groups': 2,
#           'privacy': 2,
#           'policy': 1,
#           'options': 1,
#           'custom': 2,
#           'seats': 1,
#           'employment': 1,
#           'massage': 1,
#           'parlors': 1,
#           'women': 2,
#           'prostitute': 1,
#           'mhz': 3,
#           'syringe': 1,
#           'needles': 1,
#           'skill': 1,
#           'motivation': 2,
#           'scratch': 2,
#           'starters': 1,
#           'park': 1,
#           'effect': 1,
#           'frontier': 1,
#           'foundation': 1,
#           'computer': 3,
#           'professionals': 1,
#           'responsibility': 1,
#           'cpsr': 1,
#           'initiative': 1,
#           "ol'professor": 1,
#           'suggestion': 3,
#           'geico': 2,
#           'mets': 1,
#           'sentences': 1,
#           'level': 3,
#           'integration': 1,
#           'connection': 2,
#           'editor': 1,
#           'pierce': 1,
#           'ar': 2,
#           'dealers': 1,
#           'support': 4,
#           'numbers': 3,
#           'customer': 1,
#           'assistance': 2,
#           'units': 2,
#           'radiosity': 1,
#           'radiance': 1,
#           'parts': 2,
#           'battery': 1,
#           'accessories': 1,
#           'human': 1,
#           'years': 6,
#           'trip': 1,
#           'miles': 3,
#           '#': 7,
#           'sarcasm': 1,
#           'culture': 1,
#           'lies': 1,
#           'shabak': 1,
#           'detainees': 1,
#           'interrogation': 1,
#           'statement': 2,
#           'reasons': 2,
#           'sudbury': 1,
#           'preseason': 1,
#           'amendment': 1,
#           'dod': 1,
#           'catagory': 1,
#           'state': 5,
#           'slot': 1,
#           'break': 1,
#           'door': 1,
#           'floor': 1,
#           'hall': 1,
#           'babes': 1,
#           'disney': 1,
#           'make': 1,
#           'classic': 1,
#           'ray': 1,
#           'bolger': 1,
#           'asuvm': 1,
#           'theologies': 1,
#           'mirrors': 1,
#           't': 1,
#           'zoom': 1,
#           'fills': 1,
#           'lists': 1,
#           'clock': 1,
#           'pins': 1,
#           'agents': 1,
#           'warrants': 2,
#           'guns': 2,
#           'explosives': 1,
#           'howell': 1,
#           'atf': 1,
#           'argument': 4,
#           'writer': 1,
#           'technique': 1,
#           'unit': 3,
#           'cohesion': 1,
#           'soldiers': 4,
#           'picture': 2,
#           'decompress': 1,
#           'condition': 2,
#           'mind': 2,
#           'possibile': 1,
#           'explaination': 1,
#           'spin': 1,
#           'doctors': 1,
#           'elements': 1,
#           'schedule': 1,
#           'c': 2,
#           'secret': 1,
#           'mistakes': 2,
#           'guilt': 1,
#           'feeling': 2,
#           'shoulder': 1,
#           'mapper': 1,
#           'patches': 1,
#           'soundblaster': 1,
#           'sbfm': 1,
#           'allways': 1,
#           'instruments': 2,
#           'avalaibility': 1,
#           'end': 2,
#           'comdex': 1,
#           'spring': 1,
#           'sumgait': 1,
#           'azerbaijan': 1,
#           '27th': 1,
#           'sister': 1,
#           'marina': 1,
#           'movies': 1,
#           "o'clock": 1,
#           'show': 1,
#           'theater': 2,
#           'committee': 1,
#           'yards': 1,
#           'sun': 3,
#           'sparcstation': 1,
#           'pin': 3,
#           'simm': 1,
#           'ibms': 1,
#           'issue': 3,
#           'magazine': 1,
#           'father': 2,
#           'poster': 1,
#           'heritage': 2,
#           'truth': 3,
#           'appearances': 1,
#           'nature': 1,
#           'todays': 1,
#           'wins': 1,
#           'arena': 1,
#           'cup': 1,
#           'championships': 1,
#           'uprising': 1,
#           'leadership': 1,
#           'boyadjian': 1,
#           'th': 1,
#           'goal': 2,
#           'hawks': 2,
#           'leafs': 1,
#           'losers': 1,
#           'grams': 1,
#           'stuff': 3,
#           'rpm': 1,
#           'figures': 1,
#           'copies': 1,
#           'documents': 1,
#           'crime': 2,
#           'writings': 1,
#           'armenians': 3,
#           'american': 1,
#           'tymnet': 1,
#           'billington': 1,
#           'shots': 2,
#           'saves': 1,
#           'ref': 1,
#           'devorski': 1,
#           'linesmen': 1,
#           'vines': 1,
#           'lori': 1,
#           'emacs': 1,
#           'message': 3,
#           'garbage': 1,
#           'collecting': 1,
#           'site': 2,
#           'licenses': 1,
#           'impression': 2,
#           'odometer': 1,
#           'tampering': 1,
#           'point': 6,
#           'strider': 1,
#           'ranch': 1,
#           'kind': 3,
#           'baku': 1,
#           'overabundance': 1,
#           'book': 3,
#           'venom': 1,
#           'view': 2,
#           'relativism': 1,
#           'leaders': 1,
#           'survivors': 3,
#           'hensley': 1,
#           'homosexuality': 1,
#           'while': 2,
#           'principle': 1,
#           'users': 2,
#           'hotel': 1,
#           'night': 3,
#           'copyright': 1,
#           'protection': 2,
#           'football': 1,
#           'agency': 1,
#           'bd': 1,
#           'branch': 4,
#           'davidians': 3,
#           'tc': 1,
#           'situation': 1,
#           'square': 1,
#           'ner': 1,
#           'representative': 1,
#           'position': 3,
#           'legislation': 1,
#           'images': 1,
#           'tears': 1,
#           'blood': 1,
#           'retrospect': 1,
#           'sightseeing': 1,
#           'tactics': 1,
#           'justice': 2,
#           'goaldingers': 1,
#           'processor': 1,
#           'devils': 1,
#           'guy': 1,
#           'puck': 3,
#           'corner': 1,
#           'boxer': 1,
#           'shorts': 1,
#           'plenty': 1,
#           'spf': 1,
#           'fl': 1,
#           'doctor': 1,
#           'care': 1,
#           'mutton': 1,
#           'arguments': 2,
#           'texture': 1,
#           'maps': 1,
#           'brushmapping': 1,
#           'brushmaps': 1,
#           'posting': 1,
#           'chemistry': 1,
#           'interactions': 2,
#           'sin': 1,
#           'building': 1,
#           'buses': 1,
#           'tanks': 1,
#           'courtyard': 2,
#           'pov': 1,
#           'polyray': 1,
#           'flexibel': 1,
#           'expressions': 1,
#           'windows': 6,
#           'flame': 1,
#           'story': 1,
#           'mdw': 2,
#           'mailtool': 1,
#           'trumpet': 1,
#           'parcplace': 1,
#           'exhaust': 1,
#           'valves': 1,
#           'hope': 3,
#           'parole': 1,
#           'propagation': 1,
#           'distance': 2,
#           'gamma': 1,
#           'rays': 1,
#           'thickness': 1,
#           'galaxy': 1,
#           'sensitivity': 1,
#           'superstition': 1,
#           'batf': 1,
#           'affair': 1,
#           'doctrine': 1,
#           'infallibility': 1,
#           'choice': 1,
#           'base': 1,
#           'sl': 1,
#           'versions': 1,
#           'fate': 1,
#           'friend': 1,
#           'install': 1,
#           'military': 1,
#           'competence': 1,
#           'paint': 1,
#           'saturn': 1,
#           'rocket': 1,
#           'advertiser': 1,
#           'flames': 1,
#           'apostles': 1,
#           'order': 6,
#           'christians': 2,
#           'circumcision': 1,
#           'concave': 1,
#           'outline': 1,
#           'role': 1,
#           'grips': 1,
#           'rejection': 2,
#           "jesus'commendation": 1,
#           'format': 3,
#           'trouble': 5,
#           'colors': 2,
#           'steel': 1,
#           'refutation': 1,
#           'date': 2,
#           'help': 2,
#           'preference': 1,
#           'gls': 1,
#           'spd': 1,
#           'aid': 1,
#           'citizenship': 2,
#           'arabs': 1,
#           'nds': 1,
#           'tv': 4,
#           'aerial': 1,
#           'digitizing': 1,
#           'viewpoint': 1,
#           'yount': 1,
#           'ide': 3,
#           'megs': 1,
#           'speed': 4,
#           'sprites': 2,
#           'slowdown': 1,
#           'boot': 1,
#           'dos': 4,
#           'offers': 1,
#           'matthew': 1,
#           'converge': 1,
#           'accounts': 1,
#           'baptism': 1,
#           'combination': 1,
#           'stay': 1,
#           's': 1,
#           'part': 4,
#           'catalysts': 1,
#           'oates': 1,
#           'mogilny': 1,
#           'hawerchuk': 1,
#           'version': 4,
#           'watts': 1,
#           'motor': 1,
#           'hp': 1,
#           'biberdorf': 2,
#           'azeris': 1,
#           'sound': 4,
#           'heck': 1,
#           'radio': 1,
#           'waves': 1,
#           'judge': 1,
#           'trial': 1,
#           'minute': 1,
#           'tyranny': 2,
#           'right': 4,
#           'wiretaps': 1,
#           'police': 2,
#           'service': 2,
#           'announcements': 1,
#           'lady': 1,
#           'driving': 1,
#           'lights': 1,
#           'bankers': 1,
#           'war': 6,
#           'economy': 1,
#           'cod': 1,
#           'ethernet': 1,
#           'sparcs': 1,
#           'network': 3,
#           'things': 6,
#           'behavior': 1,
#           'key': 2,
#           'u1': 1,
#           'publication': 1,
#           'claims': 1,
#           'paranoia': 1,
#           'pray': 1,
#           'legends': 1,
#           'myths': 1,
#           'entertainment': 1,
#           'direction': 1,
#           'bitch': 1,
#           'hit': 1,
#           'joint': 1,
#           'nope': 1,
#           ...}),
#  'AUX': Counter({'were': 33,
#           'be': 77,
#           'do': 52,
#           'are': 83,
#           'can': 57,
#           'could': 19,
#           'is': 191,
#           'has': 17,
#           'been': 21,
#           "'ll": 7,
#           "'ve": 12,
#           "'m": 19,
#           'got': 2,
#           'did': 14,
#           'was': 50,
#           "'d": 10,
#           "'re": 10,
#           'may': 17,
#           'being': 12,
#           'ca': 15,
#           'will': 41,
#           "'s": 26,
#           'must': 7,
#           'would': 48,
#           'does': 22,
#           'should': 15,
#           'have': 36,
#           'wo': 1,
#           'shall': 1,
#           'had': 7,
#           'might': 10,
#           'am': 13,
#           'get': 3,
#           'need': 1,
#           'deserves': 1,
#           've': 2,
#           'enjoy': 1,
#           "scripture'had": 1,
#           'w': 1}),
#  'VERB': Counter({'honking': 1,
#           'tend': 1,
#           'related': 2,
#           'see': 15,
#           'relate': 1,
#           'discussing': 1,
#           'start': 5,
#           'plan': 3,
#           'engage': 1,
#           'use': 18,
#           'power': 1,
#           'allows': 2,
#           'works': 4,
#           'purchase': 2,
#           'reserved': 1,
#           'goes': 4,
#           'lubed': 1,
#           'used': 15,
#           'say': 9,
#           'fry': 1,
#           'left': 2,
#           'deal': 3,
#           'result': 1,
#           'overstress': 1,
#           'fail': 1,
#           'deleted': 3,
#           'toss': 1,
#           'begun': 2,
#           'think': 19,
#           'made': 6,
#           'read': 8,
#           'au': 1,
#           'appears': 1,
#           'rejected': 1,
#           'intend': 3,
#           'understood': 1,
#           'mispresented': 1,
#           'sell': 4,
#           'has': 15,
#           'have': 48,
#           'come': 8,
#           'make': 18,
#           'beating': 3,
#           'enforcing': 1,
#           'cutting': 3,
#           'kill': 3,
#           'loaded': 1,
#           'puts': 1,
#           'uses': 3,
#           'seems': 8,
#           'discovered': 1,
#           'want': 18,
#           'synchronize': 1,
#           'flocked': 1,
#           'need': 11,
#           'working': 2,
#           'based': 6,
#           'work': 7,
#           'includes': 1,
#           'asking': 2,
#           'love': 2,
#           'reply': 2,
#           'exists': 1,
#           'asked': 1,
#           'underlies': 1,
#           'killed': 2,
#           'sending': 2,
#           'cheers': 1,
#           'carrying': 1,
#           'associated': 2,
#           'covered': 2,
#           'know': 28,
#           'are': 7,
#           'appreciate': 1,
#           'hearing': 1,
#           'breathe': 1,
#           'is': 16,
#           'end': 1,
#           'driven': 1,
#           'seek': 1,
#           'stood': 1,
#           'saves': 1,
#           'note': 6,
#           'released': 1,
#           'died': 1,
#           'refers': 1,
#           'forget': 4,
#           'repent': 2,
#           'become': 4,
#           'get': 30,
#           'got': 7,
#           'reading': 3,
#           'change': 2,
#           'assume': 2,
#           'lumped': 1,
#           'meant': 2,
#           'threaten': 2,
#           'do': 24,
#           'leaves': 2,
#           'called': 5,
#           'licensed': 1,
#           'guessing': 1,
#           'reverse': 1,
#           'engineered': 1,
#           'dunno': 1,
#           'hold': 5,
#           'came': 4,
#           'cares': 1,
#           'ingesting': 1,
#           'mutated': 1,
#           'done': 3,
#           'appreciated': 2,
#           'accessed': 1,
#           'using': 10,
#           'valued': 1,
#           'claim': 5,
#           'ignoring': 3,
#           'disarmed': 1,
#           'started': 6,
#           'remembering': 1,
#           'encourage': 1,
#           'like': 10,
#           'prefer': 4,
#           'offered': 1,
#           'had': 16,
#           'going': 7,
#           'defend': 2,
#           'letting': 1,
#           're': 1,
#           'open': 1,
#           'keep': 5,
#           'seem': 5,
#           'believe': 17,
#           'moves': 1,
#           'email': 2,
#           'tetaka': 1,
#           'doing': 4,
#           'stop': 2,
#           'does': 5,
#           'deter': 1,
#           'deterred': 1,
#           'manifested': 1,
#           'convert': 1,
#           'send': 6,
#           'ask': 7,
#           'practice': 1,
#           'seen': 4,
#           'hired': 1,
#           'said': 12,
#           'lds': 1,
#           'speculate': 1,
#           'written': 4,
#           'withhold': 1,
#           'display': 3,
#           'occur': 1,
#           'fooled': 1,
#           'routed': 1,
#           'receiving': 1,
#           'stopped': 2,
#           'developed': 3,
#           'agree': 4,
#           'envision': 1,
#           'dimished': 1,
#           'justified': 2,
#           'knew': 2,
#           'was': 2,
#           'spoke': 1,
#           'scare': 1,
#           'create': 2,
#           'describes': 1,
#           'fueled': 1,
#           'claimed': 3,
#           'achieve': 1,
#           'hopes': 1,
#           'reduce': 2,
#           'access': 1,
#           'optimized': 1,
#           'shared': 3,
#           'transferring': 1,
#           'indoctrinated': 1,
#           'remember': 6,
#           'complained': 1,
#           'sets': 1,
#           'belongs': 1,
#           'according': 2,
#           'offering': 1,
#           'turn': 1,
#           'jack': 1,
#           'draw': 2,
#           'means': 3,
#           'v063kcbp': 1,
#           'enables': 1,
#           'bought': 1,
#           'find': 5,
#           'reboot': 1,
#           'managed': 1,
#           'teach': 1,
#           'embarrass': 1,
#           'build': 1,
#           'liquidated': 1,
#           'starved': 1,
#           'putting': 1,
#           'allow': 2,
#           'proceed': 1,
#           'infringing': 1,
#           'designed': 3,
#           'develop': 1,
#           'enter': 1,
#           'choose': 1,
#           'contradicts': 1,
#           'typesetting': 1,
#           'became': 1,
#           'keywords': 2,
#           'accredit': 1,
#           'verifying': 1,
#           'verify': 1,
#           'meet': 2,
#           'confronted': 1,
#           'including': 5,
#           'followed': 1,
#           'double': 1,
#           'checked': 2,
#           'vomited': 1,
#           'sleep': 1,
#           'sounds': 3,
#           'furnish': 1,
#           'ordering': 1,
#           'registers': 1,
#           'takes': 4,
#           'demanded': 1,
#           'gets': 4,
#           'speeding': 1,
#           'explode': 1,
#           'contact': 1,
#           'printed': 1,
#           'judged': 1,
#           'trying': 2,
#           'preach': 1,
#           'surprised': 1,
#           'disarm': 1,
#           'connected': 2,
#           'sue': 1,
#           'thrown': 1,
#           'developing': 1,
#           'led': 3,
#           'aggravated': 1,
#           'improved': 2,
#           'recived': 1,
#           'arrive': 1,
#           'rubbed': 1,
#           'caused': 3,
#           'lose': 3,
#           'quit': 4,
#           'playing': 2,
#           'put': 9,
#           'worked': 4,
#           'pitched': 1,
#           'se': 1,
#           'looks': 5,
#           'try': 8,
#           'mapped': 1,
#           'supply': 1,
#           'proven': 1,
#           'disable': 1,
#           'proclaim': 1,
#           'look': 8,
#           'accomadate': 1,
#           'handle': 1,
#           'rnichols': 1,
#           'combined': 1,
#           'amassed': 1,
#           'following': 3,
#           'pts': 1,
#           'watch': 1,
#           'listed': 1,
#           'required': 1,
#           'sunk': 1,
#           'attatched': 1,
#           'operated': 1,
#           'asks': 1,
#           'looked': 3,
#           'happened': 2,
#           'haunt': 1,
#           'draws': 2,
#           'mean': 6,
#           'groans': 1,
#           'bother': 1,
#           'looking': 3,
#           'directed': 2,
#           'advocate': 1,
#           'failed': 1,
#           'take': 7,
#           'assemble': 1,
#           'understand': 1,
#           'insist': 2,
#           'contribute': 1,
#           'assuming': 1,
#           'fight': 1,
#           'stay': 5,
#           'shop': 1,
#           'lost': 3,
#           'believed': 1,
#           'impressed': 1,
#           'affords': 1,
#           'extract': 1,
#           'rebind': 1,
#           'replace': 2,
#           'rely': 2,
#           'registering': 2,
#           'owning': 2,
#           'point': 1,
#           'referred': 2,
#           'lying': 2,
#           'denying': 1,
#           'claims': 2,
#           'tortured': 1,
#           'talking': 3,
#           'enraptured': 1,
#           'predicted': 1,
#           'tell': 6,
#           'falls': 1,
#           'concerned': 1,
#           'stayed': 1,
#           'indicates': 1,
#           'ignored': 1,
#           'created': 5,
#           'supports': 3,
#           'scroll': 1,
#           'write': 2,
#           'solder': 1,
#           'search': 1,
#           'arrest': 1,
#           'disagree': 2,
#           'explain': 1,
#           'promote': 1,
#           'm': 1,
#           'bagged': 1,
#           'backed': 1,
#           'realize': 1,
#           'hurts': 1,
#           'file': 1,
#           'feel': 6,
#           'regret': 1,
#           'hanging': 1,
#           'attempt': 2,
#           'remap': 1,
#           'modify': 1,
#           'anounce': 1,
#           'went': 2,
#           'writes': 2,
#           'wired': 1,
#           'living': 1,
#           'todays': 1,
#           'recalled': 1,
#           'took': 2,
#           'scored': 1,
#           'harbor': 2,
#           'existing': 1,
#           'gave': 2,
#           'prevent': 1,
#           'confirming': 1,
#           'recommended': 1,
#           'thought': 5,
#           'atf': 1,
#           'burns': 1,
#           'let': 7,
#           'coming': 2,
#           'carried': 2,
#           'echo': 1,
#           'concludes': 1,
#           'joins': 1,
#           'presents': 1,
#           'lige': 1,
#           'refute': 1,
#           'mark': 1,
#           'exposed': 1,
#           'pay': 2,
#           'given': 8,
#           'comming': 1,
#           'embarrased': 1,
#           'sp': 1,
#           'tells': 1,
#           'picked': 1,
#           'sent': 1,
#           'comment': 1,
#           'pending': 1,
#           'showing': 1,
#           'replaces': 1,
#           'dying': 1,
#           'showed': 2,
#           'fired': 1,
#           'wear': 1,
#           'bring': 3,
#           'retype': 1,
#           'type': 1,
#           'errored': 1,
#           'continue': 3,
#           'manage': 1,
#           'wonder': 1,
#           'cult': 1,
#           'headed': 1,
#           'wade': 1,
#           'animated': 1,
#           'stated': 1,
#           'ignore': 2,
#           'hang': 1,
#           'judging': 1,
#           'guess': 1,
#           'blowing': 1,
#           'burning': 1,
#           'were': 3,
#           'distributed': 3,
#           'exterminated': 1,
#           'driving': 3,
#           'remembered': 1,
#           'msg': 1,
#           'handled': 1,
#           'obey': 1,
#           'implemented': 1,
#           'threatened': 1,
#           'vowing': 1,
#           'intervened': 1,
#           'prevented': 1,
#           'acting': 1,
#           'loan': 1,
#           'backup': 1,
#           'give': 4,
#           'differentating': 1,
#           'call': 4,
#           'intended': 2,
#           'concluded': 1,
#           'rules': 1,
#           'apply': 4,
#           'relates': 1,
#           'having': 8,
#           'thumbs': 1,
#           'granted': 2,
#           'remained': 1,
#           'cost': 1,
#           'receive': 2,
#           'represent': 1,
#           'deleting': 1,
#           'picking': 1,
#           'specializes': 1,
#           'appeciated': 1,
#           'produced': 1,
#           'says': 5,
#           'limited': 1,
#           'noticed': 1,
#           'played': 1,
#           'selling': 2,
#           'deliver': 1,
#           'researching': 1,
#           'tamu': 1,
#           'fide': 1,
#           'travels': 1,
#           'happens': 1,
#           'underreact': 1,
#           'monopolizes': 1,
#           'saying': 1,
#           'flashing': 1,
#           'ship': 1,
#           'consider': 2,
#           'sustains': 1,
#           'sustain': 1,
#           'criticize': 1,
#           'tried': 4,
#           'follows': 1,
#           "'": 1,
#           'second': 1,
#           'retold': 1,
#           'yelled': 1,
#           'carry': 1,
#           'crossposted': 1,
#           'set': 7,
#           'executed': 1,
#           'plots': 1,
#           'makes': 3,
#           'serving': 1,
#           'paid': 1,
#           'needed': 2,
#           'sold': 1,
#           'recovering': 1,
#           'play': 4,
#           'replying': 1,
#           'install': 1,
#           'charged': 2,
#           'agreed': 1,
#           'jold': 1,
#           'erupt': 1,
#           'fuck': 1,
#           'presented': 1,
#           'asserted': 1,
#           'posted': 3,
#           'declined': 1,
#           'felt': 1,
#           'posting': 1,
#           'demonstrating': 2,
#           'rise': 2,
#           'speaking': 1,
#           'refined': 1,
#           'provided': 2,
#           'missed': 1,
#           'score': 1,
#           'ascertain': 1,
#           'advocating': 1,
#           'customize': 1,
#           'conducted': 1,
#           'wait': 1,
#           'taken': 2,
#           'disclosed': 1,
#           'decrypt': 1,
#           'recorded': 1,
#           'maintains': 1,
#           'act': 1,
#           'protect': 1,
#           'classified': 1,
#           'interconnecting': 1,
#           'suffer': 1,
#           'depending': 1,
#           'recall': 1,
#           'hope': 2,
#           'go': 5,
#           'ittihad': 1,
#           'terakki': 1,
#           'speak': 1,
#           'heard': 1,
#           'appear': 4,
#           'accept': 3,
#           'writing': 1,
#           'soundbase': 1,
#           'promises': 1,
#           'pray': 1,
#           'presume': 1,
#           'accepting': 1,
#           'switch': 1,
#           'notice': 2,
#           'specified': 1,
#           'baptized': 1,
#           'distri': 1,
#           'buted': 1,
#           'suggest': 1,
#           'happening': 1,
#           'oppose': 1,
#           'fall': 1,
#           'contains': 2,
#           "'s": 3,
#           'rethought': 1,
#           'propagated': 1,
#           'tossed': 1,
#           'did': 6,
#           'removed': 1,
#           'spend': 3,
#           'powered': 1,
#           'apr': 1,
#           'approve': 1,
#           'becuse': 1,
#           'focus': 1,
#           'gives': 2,
#           'pass': 1,
#           'obtain': 1,
#           'dealing': 2,
#           'opposed': 1,
#           'conveyed': 1,
#           'lead': 1,
#           'abiding': 1,
#           'reveal': 1,
#           'described': 3,
#           'balancing': 1,
#           'claiming': 1,
#           'register': 1,
#           'usenet': 1,
#           'knows': 2,
#           'surprises': 1,
#           'suspect': 1,
#           'reject': 2,
#           'supposed': 1,
#           'lacks': 1,
#           'punch': 1,
#           'reaping': 1,
#           'daring': 1,
#           'flying': 1,
#           'lets': 1,
#           'fits': 1,
#           'answer': 1,
#           'maintained': 1,
#           'spied': 1,
#           'include': 1,
#           'cal': 1,
#           'bhattacharya': 1,
#           'ps': 1,
#           'pops': 1,
#           'crop': 1,
#           'resolved': 1,
#           'refused': 2,
#           'alink': 1,
#           'suppose': 2,
#           'check': 1,
#           'believing': 1,
#           'represents': 1,
#           'learn': 3,
#           'grow': 1,
#           'mature': 1,
#           'rid': 1,
#           'helps': 1,
#           'help': 3,
#           'calculated': 2,
#           'generated': 1,
#           'grant': 1,
#           'accuses': 1,
#           'accused': 1,
#           'begin': 1,
#           'select': 2,
#           'advacned': 1,
#           'prevents': 2,
#           'eating': 2,
#           'noted': 2,
#           'afford': 2,
#           'reinstalling': 1,
#           'displayed': 1,
#           'propagating': 1,
#           'commanded': 1,
#           'lives': 1,
#           'answers': 1,
#           'experienced': 1,
#           'poke': 1,
#           'priced': 1,
#           'cracked': 1,
#           'inject': 1,
#           'panic': 1,
#           'replied': 1,
#           'forced': 2,
#           'sound': 1,
#           'wish': 2,
#           'physicist': 1,
#           'octave': 1,
#           'found': 1,
#           'figured': 1,
#           'throw': 1,
#           'keeping': 1,
#           'winning': 1,
#           'irritating': 1,
#           'losing': 1,
#           'giving': 1,
#           'smoothing': 1,
#           'filtering': 1,
#           'interpret': 1,
#           'running': 1,
#           'brad': 1,
#           'generate': 1,
#           'parabola': 1,
#           'live': 3,
#           'burn': 1,
#           'taking': 1,
#           'fit': 1,
#           'explained': 1,
#           'persuaded': 1,
#           'ensure': 1,
#           'impregnate': 1,
#           'lasted': 1,
#           'earn': 1,
#           'speed': 1,
#           'run': 5,
#           'provide': 2,
#           'considering': 1,
#           'spread': 1,
#           'mount': 1,
#           'trust': 1,
#           'move': 1,
#           'begins': 1,
#           'catch': 1,
#           'ended': 1,
#           'repost': 1,
#           'bait': 1,
#           'pop': 1,
#           'filled': 1,
#           'press': 1,
#           'lighted': 1,
#           'cook': 1,
#           'compiling': 1,
#           'checking': 2,
#           'making': 3,
#           'lower': 1,
#           'drop': 1,
#           'com': 1,
#           'reaching': 1,
#           'keeps': 1,
#           'bouncing': 1,
#           'hung': 1,
#           'protected': 1,
#           'established': 1,
#           'determine': 1,
#           'replaced': 1,
#           'die': 2,
#           'obtained': 1,
#           'tuned': 1,
#           'gone': 2,
#           'follow': 1,
#           'post': 1,
#           'grissom': 1,
#           'allowed': 1,
#           'copy': 1,
#           'passed': 1,
#           'olsen': 1,
#           'holding': 1,
#           'support': 1,
#           'fighting': 1,
#           'routing': 1,
#           'chungy2': 1,
#           'crash': 1,
#           'excel': 1,
#           'manned': 1,
#           'harassed': 1,
#           'told': 2,
#           'chopped': 1,
#           'lived': 1,
#           'moved': 1,
#           'care': 2,
#           'leave': 1,
#           'broke': 1,
#           'accepted': 1,
#           'flamed': 1,
#           'persevere': 1,
#           'wondered': 1,
#           'correlate': 1,
#           'reality': 1,
#           'stolen': 1,
#           'compared': 1,
#           'save': 1,
#           'quits': 1,
#           'nested': 1,
#           'placed': 1,
#           'entering': 1,
#           'destroyed': 1,
#           'returning': 1,
#           'undressing': 1,
#           'affect': 1,
#           'talk': 2,
#           'connect': 1,
#           'needs': 1,
#           'wire': 1,
#           'pick': 1,
#           'rose': 1,
#           'projected': 1,
#           'cause': 1,
#           'comprising': 1,
#           'alleviates': 1,
#           'occuring': 1,
#           'cure': 1,
#           'sounded': 1,
#           'murdered': 1,
#           'upgrade': 1,
#           'answered': 1,
#           'drawing': 1,
#           'confirmed': 1,
#           'indicate': 1,
#           'collaborating': 1,
#           'expelled': 1,
#           'remialcsid': 1,
#           'pointing': 1,
#           'click': 1,
#           'wrote': 1,
#           'learned': 1,
#           'frustrate': 1,
#           'repenting': 1,
#           'stand': 1,
#           'getting': 1,
#           'clears': 1,
#           'buying': 1,
#           'corrupting': 1,
#           'turns': 1,
#           'fade': 1,
#           'decree': 1,
#           'depends': 1,
#           'traveling': 1,
#           'worry': 1,
#           'varying': 1,
#           'assigned': 1,
#           'increasing': 1,
#           'albicans': 1,
#           'pointed': 1,
#           'concerning': 1,
#           'disprove': 1,
#           'examined': 1,
#           'protecting': 1,
#           'denied': 1,
#           'entitled': 1,
#           'turning': 2,
#           'stimulating': 1,
#           'delete': 1,
#           'wilfred': 1,
#           'automated': 1,
#           'applies': 1,
#           'describe': 1,
#           'confined': 1,
#           'boot': 1,
#           'costs': 1,
#           'doubt': 1,
#           'refer': 1,
#           'presue': 1,
#           'choosing': 1,
#           'dragging': 1,
#           'crossed': 1,
#           'record': 1,
#           'count': 1,
#           'legislated': 1,
#           'detect': 1,
#           'regarded': 1,
#           'dashed': 1,
#           'hoping': 1,
#           'violated': 1,
#           'lesse': 1,
#           's': 1,
#           'win': 1,
#           'known': 1,
#           'orbits': 1,
#           'jacked': 1,
#           'aim': 1,
#           'watched': 1,
#           'eliminating': 1,
#           'derived': 1,
#           'calm': 1,
#           'repeat': 1,
#           'obscured': 1,
#           'swamping': 1,
#           'edgeways': 1,
#           'renouncing': 1,
#           'intrigued': 1,
#           'reversed': 1,
#           'moderate': 1,
#           'learning': 1,
#           'forgotten': 1,
#           'succeeded': 1,
#           'define': 1,
#           'side': 1,
#           'aerostitch': 1,
#           'collaborate': 1,
#           'brought': 1,
#           'formed': 1,
#           'proves': 1,
#           'miss': 1,
#           'repelled': 1,
# ...
#           'critical': 2,
#           'public': 8,
#           'key': 5,
#           'most': 5,
#           'internal': 2,
#           'own': 6,
#           'happy': 2,
#           'hard': 8,
#           'physical': 2,
#           'celestial': 1,
#           'atheistic': 1,
#           'higher': 2,
#           'theistic': 1,
#           'correct': 3,
#           'new': 11,
#           'spare': 3,
#           'national': 2,
#           'regional': 1,
#           'civil': 1,
#           'funny': 1,
#           'unknowable': 1,
#           'prefered': 1,
#           'gay': 1,
#           'unlikely': 1,
#           'similar': 2,
#           'vocal': 1,
#           'certain': 2,
#           'sacred': 1,
#           'possible': 8,
#           'tvtwm': 1,
#           'escherknot': 1,
#           'boring': 1,
#           'upper': 1,
#           'initial': 2,
#           'thankful': 1,
#           'above': 1,
#           'meaningful': 1,
#           'like': 2,
#           'standard': 6,
#           'right': 6,
#           'transgenic': 1,
#           'only': 6,
#           'loyal': 1,
#           'extraordinary': 1,
#           'extra': 2,
#           'operational': 2,
#           'liquid': 1,
#           'past': 1,
#           'few': 8,
#           "then'th": 1,
#           'different': 5,
#           'pixel': 1,
#           'fifth': 1,
#           'quintessential': 1,
#           'understandable': 1,
#           'deablable': 1,
#           'indirect': 2,
#           'final': 3,
#           'cleary': 1,
#           'implicit': 1,
#           'ordinary': 1,
#           'invaluable': 1,
#           'necessary': 2,
#           'daily': 2,
#           'great': 4,
#           'useless': 2,
#           'bad': 6,
#           'spectacular': 1,
#           'political': 1,
#           'taiwanese': 1,
#           'chinese': 1,
#           'joint': 1,
#           'unlimited': 1,
#           'fundamental': 1,
#           'moderated': 1,
#           'generic': 1,
#           'smug': 1,
#           'first': 7,
#           'renowned': 1,
#           'genuine': 1,
#           'small': 2,
#           'committed': 1,
#           'responsible': 2,
#           'general': 8,
#           'rich': 2,
#           'powerful': 1,
#           'french': 1,
#           'japanese': 2,
#           'double': 1,
#           'decent': 3,
#           'simple': 2,
#           'electromagnetical': 1,
#           'cheaper': 1,
#           'sudden': 1,
#           'awful': 3,
#           'multimillionaire': 1,
#           'grateful': 1,
#           'dead': 5,
#           'columbus': 1,
#           'long': 5,
#           'current': 1,
#           'unchanging': 1,
#           'violent': 1,
#           'non': 6,
#           'composite': 2,
#           'serious': 3,
#           'industrialized': 1,
#           'left': 1,
#           'free': 2,
#           'wrong': 2,
#           'mechanical': 1,
#           'morris': 1,
#           'remote': 2,
#           'okay': 2,
#           'plain': 1,
#           'legitimate': 2,
#           'legal': 6,
#           'registered': 1,
#           'basic': 3,
#           'familiar': 1,
#           'uniform': 1,
#           '36th': 1,
#           'last': 6,
#           'lucky': 1,
#           'montreal': 1,
#           'offensive': 2,
#           'marginal': 1,
#           'ignorant': 1,
#           'particular': 5,
#           '3rd': 1,
#           'bullpen': 1,
#           'worthless': 1,
#           'ashamed': 2,
#           'old': 11,
#           'accurate': 1,
#           'recorded': 1,
#           'early': 2,
#           'frequent': 1,
#           'affected': 1,
#           'prior': 1,
#           'several': 6,
#           'worthwhile': 1,
#           'lefthanded': 1,
#           'electronic': 2,
#           'social': 4,
#           'appropriate': 1,
#           'corporate': 1,
#           'indian': 1,
#           'human': 5,
#           'fallen': 1,
#           'sure': 4,
#           '2nd': 1,
#           'mammal': 1,
#           'likely': 3,
#           'true': 5,
#           'musical': 1,
#           'tommy': 1,
#           'subject': 1,
#           'sound': 1,
#           'homosexual': 1,
#           'effective': 1,
#           '+': 1,
#           'nm': 1,
#           'bizarre': 1,
#           'open': 1,
#           'main': 2,
#           'average': 4,
#           'statist': 1,
#           'eternal': 1,
#           'guilty': 1,
#           'huge': 1,
#           'midi': 1,
#           'stuck': 1,
#           'accessable': 1,
#           'original': 2,
#           'messianic': 1,
#           'divine': 1,
#           'grand': 1,
#           'memorial': 1,
#           'ahl': 1,
#           'major': 2,
#           'high': 6,
#           'gauthier': 1,
#           'ironic': 1,
#           'moral': 2,
#           'illegal': 1,
#           'clear': 2,
#           'dividian': 1,
#           'limbaugh': 1,
#           'genocidal': 1,
#           'socialist': 1,
#           'strongest': 1,
#           'special': 1,
#           'proprietary': 1,
#           'unpublished': 1,
#           'very': 1,
#           'specific': 1,
#           'little': 5,
#           'domestic': 1,
#           'natural': 1,
#           'best': 3,
#           'nicest': 1,
#           'sunscreen': 1,
#           'algorithmic': 1,
#           'common': 1,
#           'atomic': 2,
#           'repent': 1,
#           'vivid': 1,
#           'faster': 2,
#           'far': 1,
#           'inferior': 1,
#           'ridden': 1,
#           'next': 5,
#           'serdar': 1,
#           'argic': 1,
#           'cortical': 1,
#           'even': 1,
#           'characteristic': 1,
#           'shorter': 2,
#           'earlier': 1,
#           'russian': 1,
#           'white': 3,
#           'known': 1,
#           'black': 2,
#           'full': 5,
#           'apparent': 1,
#           'proprietory': 1,
#           'metallic': 1,
#           'rgb': 1,
#           'sonata': 1,
#           'automatic': 1,
#           'western': 1,
#           'luke': 1,
#           'lafontaine': 1,
#           'slower': 2,
#           'light': 1,
#           'enough': 1,
#           'worst': 1,
#           'blue': 2,
#           'swiss': 1,
#           'essential': 1,
#           'german': 1,
#           'amazing': 1,
#           'worse': 3,
#           'entire': 2,
#           'fun': 1,
#           'strange': 2,
#           'variable': 1,
#           'foamed': 1,
#           'total': 2,
#           'aluminum': 1,
#           'bulk': 1,
#           'older': 1,
#           'younger': 2,
#           'uchile': 1,
#           'digital': 2,
#           '_': 1,
#           'infamous': 1,
#           'manual': 3,
#           'typical': 1,
#           'visible': 1,
#           'late': 2,
#           'able': 1,
#           'helpless': 1,
#           'sincere': 2,
#           'equivalent': 1,
#           'active': 1,
#           'military': 1,
#           'international': 2,
#           'about': 1,
#           'real': 3,
#           'southern': 1,
#           'obvious': 1,
#           'straight': 1,
#           'imho': 1,
#           'false': 1,
#           'serial': 1,
#           'perverse': 1,
#           'impossible': 1,
#           'outside': 1,
#           'second': 2,
#           'calm': 1,
#           'larger': 2,
#           'directional': 1,
#           'tempest': 1,
#           'blind': 1,
#           'strong': 3,
#           '0x20': 1,
#           'fundamentalist': 1,
#           'various': 1,
#           'sober': 1,
#           'sticky': 1,
#           'usual': 1,
#           "marv'lous": 1,
#           'sorry': 2,
#           'null': 1,
#           'primary': 1,
#           'less': 2,
#           'ac': 1,
#           'severe': 3,
#           'arab': 1,
#           'israeli': 3,
#           'limited': 1,
#           'unable': 1,
#           'financial': 1,
#           'factual': 1,
#           'minor': 1,
#           'accidental': 1,
#           'doctrinal': 1,
#           'multiple': 1,
#           'deep': 2,
#           'constitutional': 1,
#           'aiaa': 1,
#           'annual': 1,
#           'interesting': 2,
#           'destructive': 1,
#           'fair': 1,
#           'orthodox': 1,
#           'romantic': 1,
#           'young': 2,
#           'concerned': 1,
#           '1st': 1,
#           'padded': 1,
#           'cal': 1,
#           'pink': 2,
#           'gregory': 1,
#           'big': 2,
#           'procedural': 1,
#           'electrical': 1,
#           'content': 2,
#           'useful': 1,
#           'absolute': 1,
#           'easter': 1,
#           'fine': 2,
#           'urban': 1,
#           'excessive': 1,
#           'arduous': 1,
#           'probable': 1,
#           'holy': 1,
#           'winfax': 1,
#           'expensive': 1,
#           'alive': 1,
#           '3db': 1,
#           '6db': 1,
#           'audio': 1,
#           'compose': 1,
#           'comparable': 1,
#           'clearer': 1,
#           'american': 1,
#           'armed': 1,
#           'separate': 1,
#           'ruinous': 1,
#           'coupla': 1,
#           'nice': 1,
#           'interested': 6,
#           'postscript': 1,
#           'mass': 1,
#           'passive': 1,
#           '25mhz': 1,
#           'pruden': 1,
#           'mobile': 1,
#           'contractual': 1,
#           'latest': 2,
#           'refreshing': 1,
#           'well': 1,
#           'exact': 2,
#           'fastest': 1,
#           'x': 1,
#           'benevolent': 1,
#           'canadian': 1,
#           'cipher': 1,
#           'random': 2,
#           'racial': 1,
#           'symmetric': 1,
#           'secret': 1,
#           'sixth': 1,
#           'superior': 1,
#           'adequate': 1,
#           'significant': 1,
#           'fresh': 1,
#           'rational': 1,
#           'invariant': 1,
#           'sufficient': 1,
#           'implausible': 1,
#           'independent': 1,
#           'federal': 1,
#           'safe': 1,
#           'scared': 1,
#           'handy': 1,
#           'evil': 2,
#           'indefinite': 1,
#           'comparative': 1,
#           'scsi': 1,
#           'worn': 1,
#           'net': 1,
#           'foolish': 1,
#           'aware': 1,
#           'informative': 1,
#           'difficult': 1,
#           'inner': 1,
#           'outer': 1,
#           'telepathy': 1,
#           'annoying': 1,
#           'british': 1,
#           'minimal': 1,
#           'unomaha': 1,
#           'objective': 2,
#           'unknown': 1,
#           'easy': 1,
#           'technical': 1,
#           'important': 2,
#           'accessible': 1,
#           'humorous': 1,
#           'silly': 1,
#           "the'unauthorized": 1,
#           'recent': 1,
#           'armenian': 1,
#           'terrorist': 1,
#           'geographical': 1,
#           'confessional': 1,
#           'lethal': 1,
#           'tear': 1,
#           'ms': 1,
#           'connect': 1,
#           'jewish': 2,
#           'wise': 1,
#           'selectable': 1,
#           'positive': 1,
#           'harder': 1,
#           'negative': 1,
#           'reasonable': 1,
#           'biblical': 1,
#           'rebellious': 2,
#           'ancient': 1,
#           'lastdrive': 1,
#           'triple': 1,
#           'invisible': 1,
#           'clearest': 1,
#           'classic': 1,
#           'portable': 1,
#           'shareable': 1,
#           'agreeable': 1,
#           'solid': 1,
#           'catholic': 1,
#           'orignial': 1,
#           'nuclear': 1,
#           'cold': 2,
#           'dipshit': 1,
#           'solar': 1,
#           'humanitarian': 1,
#           'promising': 1,
#           'hungry': 1,
#           'racist': 1,
#           'related': 1,
#           'islamic': 1,
#           'dangerous': 1,
#           'simpler': 1,
#           'formal': 1,
#           'short': 1,
#           'cryptographic': 1,
#           'damn': 1,
#           'corrupted': 1,
#           'empirical': 1,
#           'bigger': 1,
#           'axis': 1,
#           'extensive': 1,
#           'sad': 1,
#           'absurd': 1,
#           'objectionable': 1,
#           'sonic': 1,
#           'gorier': 1,
#           'thier': 1,
#           'direct': 1}),
#  'SYM': Counter({'/': 48, '$': 13, '#': 3, '+': 1, '.': 1, ':': 8, '=': 1}),
#  'ADV': Counter({'unfortunately': 2,
#           'only': 28,
#           'before': 3,
#           'now': 9,
#           'strictly': 1,
#           'always': 7,
#           'enough': 5,
#           'inevitably': 1,
#           'that': 3,
#           'however': 7,
#           'simply': 4,
#           'even': 11,
#           'legally': 1,
#           'rrally': 1,
#           'too': 10,
#           'perfectly': 2,
#           'later': 6,
#           'probably': 5,
#           'late': 1,
#           'already': 3,
#           'all': 12,
#           'besides': 1,
#           'just': 24,
#           'no': 1,
#           'longer': 2,
#           'usually': 4,
#           'back': 4,
#           'recently': 1,
#           'much': 13,
#           'very': 20,
#           'about': 6,
#           'infinitely': 1,
#           'especially': 3,
#           'so': 29,
#           'approximately': 2,
#           "dont't": 1,
#           'here': 13,
#           'more': 10,
#           'evidently': 1,
#           'really': 12,
#           'at': 8,
#           'least': 4,
#           'though': 3,
#           'also': 29,
#           'never': 14,
#           'actually': 5,
#           'pettefar': 1,
#           'then': 18,
#           'practically': 1,
#           'yet': 6,
#           'directly': 2,
#           'maybe': 3,
#           'there': 7,
#           'most': 3,
#           'else': 2,
#           'thus': 3,
#           'once': 2,
#           'as': 17,
#           'well': 10,
#           'away': 8,
#           'anyway': 5,
#           'irrevocably': 1,
#           'in': 3,
#           'completely': 3,
#           'genuinely': 1,
#           'independantly': 2,
#           'sometimes': 1,
#           'almost': 2,
#           'certainly': 4,
#           'bjorndahl': 1,
#           'still': 11,
#           'ever': 3,
#           'btw': 2,
#           'effectively': 1,
#           'proudly': 1,
#           'soon': 2,
#           'again': 4,
#           'above': 3,
#           'somewhere': 3,
#           'incredibly': 1,
#           'around': 3,
#           'basically': 2,
#           'ago': 1,
#           "interrogators'policy": 1,
#           'quite': 5,
#           'far': 9,
#           'apparently': 2,
#           'pretty': 1,
#           'instead': 2,
#           'therefore': 4,
#           'partly': 2,
#           'somehow': 1,
#           'personally': 1,
#           'elsewhere': 2,
#           'xwebster': 1,
#           'continually': 1,
#           'truly': 4,
#           'of': 1,
#           'currently': 2,
#           'doubly': 1,
#           'widely': 2,
#           'systematically': 1,
#           'home': 2,
#           'specifically': 1,
#           'badly': 1,
#           'seriously': 2,
#           'tremendously': 1,
#           'faster': 3,
#           'triple': 1,
#           'consequently': 1,
#           'neely': 1,
#           'possibly': 1,
#           'n5gjm': 1,
#           'repeatedly': 1,
#           'any': 1,
#           'less': 4,
#           'often': 1,
#           'purely': 2,
#           'particularly': 2,
#           'rather': 1,
#           'over': 2,
#           '#': 2,
#           'blatantly': 1,
#           'harmfully': 1,
#           'globally': 2,
#           'virtually': 1,
#           'up': 2,
#           'off': 1,
#           'previously': 1,
#           'calgary': 1,
#           'regardless': 1,
#           'pletely': 1,
#           'universally': 1,
#           'perhaps': 3,
#           'thereof': 1,
#           'overly': 1,
#           "being'punished'by": 1,
#           'la': 1,
#           'anytime': 1,
#           'down': 1,
#           'immediately': 1,
#           'easily': 1,
#           'commonly': 1,
#           'greatly': 1,
#           'mildly': 1,
#           'finally': 1,
#           'fast': 1,
#           'hard': 1,
#           'appoximately': 1,
#           'after': 2,
#           'sure': 1,
#           'nearly': 1,
#           'successfully': 1,
#           'exactly': 4,
#           'supposedly': 1,
#           'highly': 1,
#           'right': 1,
#           'suddenly': 1,
#           'cf947': 1,
#           'wide': 1,
#           'anecdotally': 1,
#           'nonetheless': 1,
#           'on': 1,
#           'fundamentally': 1,
#           'poorly': 1,
#           'occasionally': 1,
#           'either': 1,
#           'long': 1,
#           'first': 3,
#           'slightly': 1,
#           'independently': 1,
#           'totally': 1,
#           "did'stay'were": 1,
#           'originally': 1,
#           'steadily': 1,
#           'otherwise': 1,
#           'essentially': 1,
#           'inherently': 1,
#           'together': 1,
#           'inside': 1,
#           'out': 1,
#           'definitely': 1,
#           'alone': 1,
#           'rapidly': 1,
#           'absolutely': 1,
#           'purposefully': 1,
#           'publically': 1,
#           'aka': 1,
#           'aside': 1,
#           'super': 1,
#           'smelly': 1,
#           'newly': 1})}

# %%
print(len(pos_dict), len(ent_dict), len(token_bert2spacy))
# Out:
# 17 15 4295

# %%
pos_dict.keys()
# Out:
# dict_keys(['DET', 'NUM', 'NOUN', 'AUX', 'VERB', 'PUNCT', 'INTJ', 'X', 'PROPN', 'CCONJ', 'PART', 'PRON', 'SCONJ', 'ADP', 'ADJ', 'SYM', 'ADV'])

# %%
ent_dict.keys()
# Out:
# dict_keys(['CARDINAL', 'QUANTITY', 'MONEY', 'ORG', 'PERSON', 'DATE', 'ORDINAL', 'NORP', 'GPE', 'TIME', 'PERCENT', 'LAW', 'PRODUCT', 'LOC', 'EVENT'])

# %% [markdown]
# # Read state-word dictionary

# %%
state_dict = {}
state_freq = {}
with codecs.open('../../local/bertnet_0.0.4.10.4_outputs/bertnet_dev_epoch_17_s2w.txt', encoding='utf-8') as fd:
    lines = fd.readlines()
    for li, l in enumerate(lines):
        if(l.startswith('state') and li %3 == 0):
            l = l[:-1].split()
            state_id = l[1]
            freq = l[3]
            freq_no_sw = l[5]
            state_freq[state_id] = {'freq': float(freq), 'freq_no_sw': float(freq_no_sw)}
            state_dict[state_id] = []
        elif(lines[li - 1].startswith('state')):
            words = l.split(' | ')
            for w in words[:-1]:
                w = w.split()
#                 print(w)
                state_dict[state_id].append((w[0], float(w[1])))

# %% [markdown]
# ## Measurement of alignment 1, dominate word set
# * Definition: W(s) 95% dominate word set = the set of words that account for the 95% of state / POS vocab.
# * if W(s) \in W(POS) we say s align with a pos
#
# ## Measurement of alignment 2, word occurance
# * If 50% of state word occurance exist in a POS dominate set, then view this as an alignment

# %% [markdown]
# ## Implementation of dominate word set alignment

# %%
# find non stop states 

non_sw_states = []
for s in state_freq: 
    if(state_freq[s]['freq_no_sw'] / float(state_freq[s]['freq']) > 0.5):
        non_sw_states.append(s)
print('%d non stop states' % len(non_sw_states))
# Out:
# 1351 non stop states

# %%
non_sw_states[:10]
# Out:
# ['171', '476', '710', '254', '1419', '1972', '403', '1488', '1556', '243']

# %%
# for each non-SW state, calculate their 95% vocab

state_dominate_set = {}
for s in non_sw_states:
    freq = state_freq[s]['freq']
    wf_cumu = 0
    state_dominate_set[s] = []
    for w, wf in state_dict[s]:
        wf_cumu += wf
        if(wf_cumu / freq < 0.9): 
            state_dominate_set[s].append(w)

# %%
# remove subwords clusters

def test_subword_cluster(wset):
    """if half of the cluster is subwords, then this is a subword cluster"""
    set_len = len(wset)
    num_subwords = 0
    for w in wset:
        if(w.startswith('##')): num_subwords += 1
        if(len(w) <= 2): num_subwords += 1
    if(num_subwords > set_len // 2): return True
    else: return False
    
non_sw_states = []
for s in state_dominate_set:
    if(test_subword_cluster(state_dominate_set[s])): pass
    else: non_sw_states.append(s)

# %%
len(non_sw_states)
# Out:
# 1060

# %%
# convert dominate set to gpt2 tokenization

state_dominate_set_gpt_token = {}
for s in non_sw_states:
    w_ = []
    for w in state_dominate_set[s]:
        if(w in token_bert2spacy):
            spacy_tokens_w = token_bert2spacy[w].keys()
            spacy_tokens_w = set([t.lower() for t in spacy_tokens_w])
            w_.extend(list(spacy_tokens_w))
        else: w_.append(w)
    state_dominate_set_gpt_token[s] = set(w_)

# %%
non_sw_states[:10]
# Out:
# ['476', '710', '254', '1419', '1972', '403', '1488', '1556', '243', '1410']

# %%
state_dominate_set_gpt_token['710']
# Out:
# {'abuse',
#  'accident',
#  'attack',
#  'attacks',
#  'bad',
#  'badwindow',
#  'conflict',
#  'crash',
#  'crime',
#  'crimes',
#  'criminals',
#  'damage',
#  'dangerous',
#  'dead',
#  'death',
#  'deathbed',
#  'deaths',
#  'destroyed',
#  'destruction',
#  'die',
#  'died',
#  'disease',
#  'error',
#  'errored',
#  'errors',
#  'evil',
#  'failure',
#  'fault',
#  'genocide',
#  'harm',
#  'hate',
#  'hatred',
#  'hell',
#  'hellbound',
#  'hit',
#  'hurt',
#  'incident',
#  'injury',
#  'kill',
#  'killed',
#  'killfile',
#  'killing',
#  'lose',
#  'loss',
#  'lost',
#  'massacre',
#  'mistake',
#  'murder',
#  'murdered',
#  'murders',
#  'pain',
#  'penalty',
#  'problem',
#  'problems',
#  'punish',
#  'punishment',
#  'sick',
#  'sin',
#  'sinful',
#  'sorry',
#  'suicidede',
#  'trouble',
#  'violence',
#  'worse',
#  'worst',
#  'wrong'}

# %%
# calculate 95% vocab of POS 

pos_dominate_set = {}

for p in pos_dict:
    full_occ = float(sum(c for w, c in pos_dict[p].most_common()))
    wf_cumu = 0
    wset = []
    for w, c in pos_dict[p].most_common():
        wf_cumu += c
        if(wf_cumu / full_occ < 0.95): wset.append(w.lower())
    pos_dominate_set[p] = set(wset)
    print('dominate set size for %s = %d' % (p, len(wset)))
# Out:
# dominate set size for DET = 7
# dominate set size for NUM = 142
# dominate set size for NOUN = 1585
# dominate set size for AUX = 24
# dominate set size for VERB = 768
# dominate set size for PUNCT = 8
# dominate set size for INTJ = 21
# dominate set size for X = 27
# dominate set size for PROPN = 670
# dominate set size for CCONJ = 3
# dominate set size for PART = 3
# dominate set size for PRON = 31
# dominate set size for SCONJ = 16
# dominate set size for ADP = 21
# dominate set size for ADJ = 482
# dominate set size for SYM = 3
# dominate set size for ADV = 160

# %%
len(state_dominate_set_gpt_token['243'])
# Out:
# 67

# %%
len(state_dominate_set_gpt_token['243'].intersection(pos_dominate_set['ADV']))
# Out:
# 37

# %%
# calculate coverage
# TODO: change vocabulary based matching to occurance based matching
# Q: why no alignment with ADV?

alignment = {}
thres = 0.5
covered_pos = []
aligned_states = 0
for s in state_dominate_set_gpt_token:
    for p in pos_dominate_set:
        overlap = state_dominate_set_gpt_token[s].intersection(pos_dominate_set[p])
        overlap = len(overlap) / float(len(state_dominate_set_gpt_token[s]))
        if(overlap > thres):
            print('state %s aligned with POS %s, overlap %.2f' % (s, p, overlap))
            covered_pos.append(p)
            aligned_states += 1
            if(p not in alignment): alignment[p] = [s]
            else: alignment[p].append(s)
covered_pos = set(covered_pos)
# Out:
# state 254 aligned with POS PROPN, overlap 0.55
# state 1972 aligned with POS NOUN, overlap 0.61
# state 1488 aligned with POS ADJ, overlap 0.54
# state 243 aligned with POS ADV, overlap 0.55
# state 1410 aligned with POS ADJ, overlap 0.59
# state 305 aligned with POS NOUN, overlap 0.60
# state 127 aligned with POS NOUN, overlap 0.58
# state 568 aligned with POS NOUN, overlap 0.52
# state 555 aligned with POS NOUN, overlap 0.61
# state 935 aligned with POS ADJ, overlap 0.54
# state 66 aligned with POS NOUN, overlap 0.56
# state 1514 aligned with POS NOUN, overlap 0.51
# state 1291 aligned with POS NOUN, overlap 0.51
# state 1579 aligned with POS NOUN, overlap 0.52
# state 1461 aligned with POS NOUN, overlap 0.54
# state 1064 aligned with POS NOUN, overlap 0.55
# state 1286 aligned with POS NOUN, overlap 0.54
# state 1450 aligned with POS NOUN, overlap 0.55
# state 123 aligned with POS NOUN, overlap 0.52
# state 1967 aligned with POS NOUN, overlap 0.62
# state 165 aligned with POS NOUN, overlap 0.67
# state 1816 aligned with POS VERB, overlap 1.00
# state 1010 aligned with POS NOUN, overlap 0.60
# state 136 aligned with POS NOUN, overlap 0.61
# state 278 aligned with POS NOUN, overlap 0.57
# state 1839 aligned with POS NOUN, overlap 0.51
# state 1004 aligned with POS PROPN, overlap 0.55
# state 581 aligned with POS NOUN, overlap 0.61
# state 178 aligned with POS NOUN, overlap 0.53
# state 1129 aligned with POS NOUN, overlap 0.59
# state 1547 aligned with POS NOUN, overlap 0.55
# state 1748 aligned with POS NOUN, overlap 0.52
# state 143 aligned with POS NOUN, overlap 0.54
# state 1937 aligned with POS NOUN, overlap 0.52
# state 277 aligned with POS NOUN, overlap 0.50
# state 1416 aligned with POS NOUN, overlap 0.52
# state 96 aligned with POS NOUN, overlap 0.54
# state 161 aligned with POS NOUN, overlap 0.53
# state 215 aligned with POS NOUN, overlap 0.53
# state 1177 aligned with POS NOUN, overlap 0.52
# state 418 aligned with POS NOUN, overlap 0.56
# state 726 aligned with POS NOUN, overlap 0.52
# state 204 aligned with POS NOUN, overlap 0.52
# state 1546 aligned with POS NOUN, overlap 0.54
# state 1624 aligned with POS NOUN, overlap 0.56
# state 994 aligned with POS NOUN, overlap 0.51
# state 1049 aligned with POS NOUN, overlap 0.52
# state 260 aligned with POS NOUN, overlap 0.53
# state 1435 aligned with POS NOUN, overlap 0.57
# state 212 aligned with POS NOUN, overlap 0.53
# state 879 aligned with POS NOUN, overlap 0.55
# state 1372 aligned with POS NOUN, overlap 0.53
# state 74 aligned with POS NOUN, overlap 0.65
# state 237 aligned with POS PROPN, overlap 0.58
# state 398 aligned with POS NOUN, overlap 0.53
# state 213 aligned with POS VERB, overlap 0.57
# state 134 aligned with POS NUM, overlap 0.54
# state 1217 aligned with POS VERB, overlap 0.53

# %%
print(aligned_states)
# Out:
# 58

# %% [markdown]
# **This is to say, with the dominate word set measurement, there are 237 out of 2000 states align with pre-defined POS**

# %% [markdown]
# ## Implementation of word occurrence alignment, note that this might be a distribution shift problem here
