# %% [markdown]
# # Simple LDA Test
#
# Copied from https://scikit-learn.org/stable/auto_examples/applications/plot_topics_extraction_with_nmf_lda.html

# %%
from time import time
import matplotlib.pyplot as plt

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from sklearn.datasets import fetch_20newsgroups

# %%
n_samples = 10000
n_features = 1000
n_components = 50
n_top_words = 20

# %%
def plot_top_words(model, feature_names, n_top_words, title):
    fig, axes = plt.subplots(2, 5, figsize=(30, 15), sharex=True)
    axes = axes.flatten()
    for topic_idx, topic in enumerate(model.components_):
        top_features_ind = topic.argsort()[:-n_top_words - 1:-1]
        top_features = [feature_names[i] for i in top_features_ind]
        weights = topic[top_features_ind]

        ax = axes[topic_idx]
        ax.barh(top_features, weights, height=0.7)
        ax.set_title(f'Topic {topic_idx +1}',
                     fontdict={'fontsize': 30})
        ax.invert_yaxis()
        ax.tick_params(axis='both', which='major', labelsize=20)
        for i in 'top right left'.split():
            ax.spines[i].set_visible(False)
        fig.suptitle(title, fontsize=40)

    plt.subplots_adjust(top=0.90, bottom=0.05, wspace=0.90, hspace=0.3)
    plt.show()

# %%
print("Loading dataset...")
t0 = time()
data, _ = fetch_20newsgroups(shuffle=True, random_state=1,
                             remove=('headers', 'footers', 'quotes'),
                             return_X_y=True)
data_samples = data[:n_samples]
print("done in %0.3fs." % (time() - t0))
# Out:
# Loading dataset...
# done in 1.608s.

# %%
print(len(data), len(data_samples))
# Out:
# 11314 10000

# %%
len(data_samples[0]), len(data_samples[1]), len(data_samples[2])
# Out:
# (852, 546, 698)

# %%
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2,
                                   max_features=n_features,
                                   stop_words='english')
t0 = time()
tfidf = tfidf_vectorizer.fit_transform(data_samples)
print("done in %0.3fs." % (time() - t0))
# Out:
# done in 1.479s.

# %%
tfidf[0]
# Out:
# <1x1000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 24 stored elements in Compressed Sparse Row format>

# %%
print("Extracting tf features for LDA...")
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2,
                                max_features=n_features,
                                stop_words='english')
t0 = time()
tf = tf_vectorizer.fit_transform(data_samples)
print("done in %0.3fs." % (time() - t0))
print()
# Out:
# Extracting tf features for LDA...
# done in 1.437s.

# %%
tf[0]
# Out:
# <1x1000 sparse matrix of type '<class 'numpy.int64'>'
# 	with 24 stored elements in Compressed Sparse Row format>

# %%
print('\n' * 2, "Fitting LDA models with tf features, "
      "n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
lda = LatentDirichletAllocation(n_components=n_components, max_iter=5,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=0)
t0 = time()
lda.fit(tf)
print("done in %0.3fs." % (time() - t0))
# Out:
#  Fitting LDA models with tf features, n_samples=10000 and n_features=1000...
# done in 30.327s.

# %%
tf_feature_names = tf_vectorizer.get_feature_names()
# Out:
# /home/s1946695/miniconda3/envs/_lm_adaptation_dev/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
for i in lda.components_[13].argsort()[: -20: -1]:
    print(tf_feature_names[i])
# Out:
# card
# drivers
# driver
# cards
# video
# windows
# mode
# vga
# tell
# graphics
# 03
# based
# new
# 24
# hi
# recently
# thank
# market
# uses

# %%
plot_top_words(lda, tf_feature_names, n_top_words, 'Topics in LDA model')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_29659/3903690502.py in <module>
# ----> 1 plot_top_words(lda, tf_feature_names, n_top_words, 'Topics in LDA model')
#
# /tmp/ipykernel_29659/3527917972.py in plot_top_words(model, feature_names, n_top_words, title)
#       7         weights = topic[top_features_ind]
#       8
# ----> 9         ax = axes[topic_idx]
#      10         ax.barh(top_features, weights, height=0.7)
#      11         ax.set_title(f'Topic {topic_idx +1}',
#
# IndexError: index 10 is out of bounds for axis 0 with size 10
