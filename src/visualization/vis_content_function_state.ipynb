# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
sns.set(rc={'figure.figsize':(4,4), 'figure.dpi': 200})

# %%
df = {'Entropy': [1.24, 0.81, 0.9939, 0.9046], 'Type': ['Content', 'Function', 'Content', 'Function'], 'Embeddings': ['BertZero', 'BertZero', 'BertLast', 'BertLast']}
df = pd.DataFrame(df)
g = sns.catplot(x='Embeddings', y='Entropy', hue='Type', data=df, kind='bar')
plt.legend(loc='upper right')
